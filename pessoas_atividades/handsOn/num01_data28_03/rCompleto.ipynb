# %%
library(tidyverse)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.3.0 --
#
# v ggplot2 3.2.1     v purrr   0.3.3
# v tibble  2.1.3     v dplyr   0.8.3
# v tidyr   1.0.0     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.4.0
#
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
library(janitor)
# Out:
# Attaching package: 'janitor'
#
#
# The following objects are masked from 'package:stats':
#
#     chisq.test, fisher.test

# %%
iris %>% 
    clean_names() %>% 
    write_csv('floresDados.csv')

# %%
df <- iris %>% 
    clean_names()

# %%
head(df)
# Out:
#   sepal_length sepal_width petal_length petal_width species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
df %>% 
    ggplot(aes(sepal_length, sepal_width, col=species))+
    geom_point(size=3)
# Out:
# plot without title

# %%
df %>% 
    ggplot(aes(sepal_length, fill=species))+
    geom_histogram()
    # geom_histogram(alpha=.5, position="identity")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
df %>% 
    ggplot(aes(sepal_length, fill=species))+
    geom_histogram(col='black')+
    facet_wrap(~ species)+
    theme(legend.position = 'bottom')
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
df %>% 
    ggplot(aes(petal_length, petal_width, col=species))+
    geom_point(size=3)
# Out:
# plot without title

# %%
df %>% 
    ggplot(aes(species, sepal_length, fill=species))+
    geom_boxplot()
# Out:
# plot without title

# %%
aux <- df %>% 
    gather(nomeCol, valor, -species)

# %%
head(aux)
# Out:
#   species nomeCol      valor
# 1 setosa  sepal_length 5.1
# 2 setosa  sepal_length 4.9
# 3 setosa  sepal_length 4.7
# 4 setosa  sepal_length 4.6
# 5 setosa  sepal_length 5.0
# 6 setosa  sepal_length 5.4

# %%
glimpse(aux)
# Out:
# Observations: 600
# Variables: 3
# $ species <fct> setosa, setosa, setosa, setosa, setosa, setosa, setosa, set...
# $ nomeCol <chr> "sepal_length", "sepal_length", "sepal_length", "sepal_leng...
# $ valor   <dbl> 5.1, 4.9, 4.7, 4.6, 5.0, 5.4, 4.6, 5.0, 4.4, 4.9, 5.4, 4.8,...

# %%
aux %>% 
    ggplot(aes(species, valor, fill=species))+
    geom_boxplot()+
    facet_wrap(~ nomeCol, nrow=1)+
    theme(legend.position = 'bottom')
# Out:
# plot without title

# %%
GGally::ggpairs(df, mapping = aes(color = species))
# Out:
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
('GGally')
# Out:
# Installing package into 'C:/Users/jardi/OneDrive/Documentos/R/win-library/3.6'
# (as 'lib' is unspecified)
#
# also installing the dependency 'reshape'
#   There is a binary version available but the source version is later:
#        binary source needs_compilation
# GGally  1.4.0  1.5.0             FALSE
#
# package 'reshape' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\jardi\AppData\Local\Temp\RtmpcvMjks\downloaded_packages
# installing the source package 'GGally'
