# %% [markdown]
# # Gerando banco de dados
#
# Aqui vamos unir os dados que serão explorados e alimentarão a modelagem preditiva.
#
# São dados diários do mercado (abertura, fechamento, máximo, mínimo, volume), envolvendo 100 empresas.

# %%
library(tidyverse)
library(quantmod)
library(janitor)

# limpando a memoria
rm(list = ls())

###### FUNÇÕES UTILIZADAS ######

obtemAcaoXts <- function(codigo, dataIni='2017-01-01', dataFim='2020-01-01'){
  # xts é um formato de tabela de series temporais do R
  # essa função retorna o numero de linhas da 
  # de uma ação obtida no quantmod de 2017 a 2020
  
  aux = getSymbols(
    codigo,
    from = as.Date(dataIni),
    to = as.Date(dataFim),
    auto.assign = F
  ) 
  
  return(aux)
}

numLinhas <- function(xtsAcao){
  # retorna o numero de linha de um xts
  
  return(nrow(xtsAcao))
}

calculaModa <- function(x){
  # calcula a moda
  # o intuito é pegar as ações com numero de linhas parecidas
  
  ux <- unique(x)
  ux[which.max(tabulate(match(x, ux)))]
}

xtsParaDf <- function(xts){
  # pega um xts e retorna um tibble com a coluna data
  # e os nomes das colunas limpos
  
  dataXts <- index(xts)
  
  df <- xts %>% 
    as_tibble() %>% 
    mutate(
      data = dataXts
    ) %>% 
    clean_names()
  
  return(df)
}

###### FUNÇÕES UTILIZADAS ######

# carregando codigos da Ibovespa e 
codigos <- read_lines('codigosIbrx100.txt')
#codDf <- read_csv('codigosIbovespIbrx100.csv')

# filtrando as 100 acoes mais liquidas
# que já fazem parte do ibovespa
#codDf <- codDf %>% 
#  filter(indice != 'ibovespa')
  
# obtendo códigos 
#codigos <- codDf %>% 
#  select(codigo) %>% 
#  as_vector()

# loop para obter vetor com numero de linhas das acoes
quantLinhasIbrx100 = map_int(
  codigos,
  function(codigo){
    codigo %>% 
      obtemAcaoXts() %>% 
      numLinhas()
  }
)

# calcula quantidade de linhas que mais aparecem  
modaLinhas <- calculaModa(quantLinhasIbrx100)

# vetor para selecionar ações com mais linhas
logicoMaxLinhas <- quantLinhasIbrx100 == modaLinhas

# filtrando ações desejadas na tabela
# codDf <- codDf %>% 
#  filter(logicoMaxLinhas) 

# codigos alvo
codAlvos <- codigos
#  select(codigo) %>% 
#  as_vector()

# agora vamos fazer um merge de todos os dados
# para realizar essa união vamos separar 1 ação 
# e ir unindo as demais nela
acoesDf <- codAlvos[1] %>% 
  obtemAcaoXts() %>% 
  xtsParaDf()

# atualiza o vetor com os ´codigos
codAlvos <- codAlvos[-1]

# vai fazendo a união dos dados pela coluna data
for (codigo in codAlvos) {
  
  # obtem os dados da ação
  df <- codigo %>% 
    obtemAcaoXts() %>% 
    xtsParaDf()
  
  # faz o merge no DF final
  acoesDf <- acoesDf %>% 
    left_join(df)
}

# salvando dados
# ressaltando que essas fazem parte das 100
# mais liquidas na data 15/02/2020
# com algumas faltantes (devido a API para obter os dados)
acoesDf %>% 
  write_csv('dadosAcoesBrV2.csv')

# limpando a memoria
rm(list = ls())
# Out:
# Warning message:
# "VALE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "ITUB4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "BBDC4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "B3SA3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "PETR4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "ABEV3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "BBAS3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "PETR3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "ITSA4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "LREN3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "JBSS3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "MGLU3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "WEGE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "BBDC3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "SUZB3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "RADL3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "VIVT4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "GNDI3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "EQTL3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "RENT3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "RAIL3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "BBSE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "UGPA3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "SBSP3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "CCRO3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "BRDT3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "LAME4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "HYPE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "BRFS3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "GGBR4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "EGIE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "ENGI11.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "TIMP3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "COGN3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "ENEV3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "VVAR3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "SANB11.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "SULA11.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "BTOW3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "YDUQ3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "KLBN11.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "PCAR3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "CMIG4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "BRML3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "HAPV3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "IRBR3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "ELET3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "EMBR3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "CSAN3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "BPAC11.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "TRPL4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "AZUL4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "CPLE6.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "TOTS3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "CRFB3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "QUAL3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "FLRY3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "BRAP4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "ELET6.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "MULT3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "CIEL3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "TAEE11.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "SAPR11.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "CYRE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "CESP6.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "ENBR3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "BRKM5.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "CPFE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "CSNA3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "PSSA3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "LIGT3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "LCAM3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "MRVE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "MRFG3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "LINX3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "GOAU4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "ODPV3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "EZTC3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "DTEX3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "USIM5.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "IGTA3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "BRSR6.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "MDIA3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "CSMG3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "CMIG3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "PRIO3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "ECOR3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "CVCB3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "HGTX3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "BEEF3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "BPAN4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "MOVI3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "MYPK3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "SLCE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "GOLL4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "SMLS3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "RAPT4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "VALE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Warning message:
# "Calling `as_tibble()` on a vector is discouraged, because the behavior is likely to change in the future. Use `tibble::enframe(name = NULL)` instead.
# This warning is displayed once per session."
# Warning message:
# "ITUB4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "BBDC4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "B3SA3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "PETR4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "ABEV3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "BBAS3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "PETR3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "ITSA4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "LREN3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "JBSS3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "MGLU3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "WEGE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "BBDC3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "SUZB3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "RADL3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "VIVT4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "GNDI3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "EQTL3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "RENT3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "RAIL3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "BBSE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "UGPA3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "SBSP3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "CCRO3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "BRDT3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "LAME4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "HYPE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "BRFS3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "GGBR4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "EGIE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "ENGI11.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "TIMP3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "COGN3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "ENEV3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "VVAR3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# ...
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "QUAL3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "FLRY3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "BRAP4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "ELET6.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "MULT3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "CIEL3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "TAEE11.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "SAPR11.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "CYRE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "CESP6.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "ENBR3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "BRKM5.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "CPFE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "CSNA3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "PSSA3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "LIGT3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "LCAM3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "MRVE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "MRFG3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "LINX3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "GOAU4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "ODPV3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "EZTC3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "DTEX3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "USIM5.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "IGTA3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "BRSR6.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "MDIA3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "CSMG3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "CMIG3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "PRIO3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "ECOR3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "CVCB3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "HGTX3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "BEEF3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "BPAN4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "MOVI3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "MYPK3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "SLCE3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "GOLL4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "SMLS3.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
# Warning message:
# "RAPT4.SA contains missing values. Some functions will not work if objects contain missing values in the middle of the series. Consider using na.omit(), na.approx(), na.fill(), etc to remove or replace them."
# Warning message:
# "'indexClass<-' is deprecated.
# Use 'tclass<-' instead.
# See help("Deprecated") and help("xts-deprecated")."
# Joining, by = "data"
